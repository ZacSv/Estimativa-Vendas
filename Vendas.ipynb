# %%
from sklearn import linear_model
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Definindo modelo de Regressão LineaR
base = pd.read_excel("Base.xlsx")
reg = linear_model.LinearRegression()

# %%
#Importando a base de dados e definindo os coeficientes angular e linear
reg.fit(base["Investimento em marketing"].values.reshape(-1, 1), base["Venda Qtd"])
reg.coef_
reg.intercept_
# Out:
# 49.200323514387804

# %%
plt.scatter(base['Investimento em marketing'], base['Venda Qtd'])
x = np.array(base['Investimento em marketing'])
y = reg.intercept_ + x*reg.coef_
plt.plot(x, y, "r")

# %%
reg.predict([[75]])
# Out:
# array([342.18304104])

# %%
plt.scatter(base['Investimento em marketing'], base['Venda Qtd'])
plt.scatter(75, reg.predict([[75]])[0], color = 'k')
x = np.array(base['Investimento em marketing'])
y = reg.intercept_ + x*reg.coef_
plt.plot(x, y, "r")
